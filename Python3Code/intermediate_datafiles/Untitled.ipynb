# %%
import pandas as pd

# %%
chap4new = pd.read_csv("chapter4_result.csv")

# %%
chap4old = pd.read_csv("chapter4_result_old.csv")

# %%
for i in chap4new.columns:
    print(i)
# Out:
# Unnamed: 0
# acc_phone_x
# acc_phone_y
# acc_phone_z
# acc_watch_x
# acc_watch_y
# acc_watch_z
# gyr_phone_x
# gyr_phone_y
# gyr_phone_z
# gyr_watch_x
# gyr_watch_y
# gyr_watch_z
# hr_watch_rate
# labelOnTable
# labelSitting
# labelWashingHands
# labelWalking
# labelStanding
# labelDriving
# labelEating
# labelRunning
# light_phone_lux
# mag_phone_x
# mag_phone_y
# mag_phone_z
# mag_watch_x
# mag_watch_y
# mag_watch_z
# press_phone_pressure
# pca_1
# pca_2
# pca_3
# pca_4
# pca_5
# pca_6
# pca_7
# acc_phone_x_temp_mean_ws_120
# acc_phone_y_temp_mean_ws_120
# acc_phone_z_temp_mean_ws_120
# acc_watch_x_temp_mean_ws_120
# acc_watch_y_temp_mean_ws_120
# acc_watch_z_temp_mean_ws_120
# gyr_phone_x_temp_mean_ws_120
# gyr_phone_y_temp_mean_ws_120
# gyr_phone_z_temp_mean_ws_120
# gyr_watch_x_temp_mean_ws_120
# gyr_watch_y_temp_mean_ws_120
# gyr_watch_z_temp_mean_ws_120
# hr_watch_rate_temp_mean_ws_120
# light_phone_lux_temp_mean_ws_120
# mag_phone_x_temp_mean_ws_120
# ...

# %%
for i in chap4old.columns:
    print(i)
# Out:
# Unnamed: 0
# acc_phone_x
# acc_phone_y
# acc_phone_z
# acc_watch_x
# acc_watch_y
# acc_watch_z
# gyr_phone_x
# gyr_phone_y
# gyr_phone_z
# gyr_watch_x
# gyr_watch_y
# gyr_watch_z
# hr_watch_rate
# labelOnTable
# labelSitting
# labelWashingHands
# labelWalking
# labelStanding
# labelDriving
# labelEating
# labelRunning
# light_phone_lux
# mag_phone_x
# mag_phone_y
# mag_phone_z
# mag_watch_x
# mag_watch_y
# mag_watch_z
# press_phone_pressure
# pca_1
# pca_2
# pca_3
# pca_4
# pca_5
# pca_6
# pca_7
# acc_phone_x_temp_mean_ws_120
# acc_phone_y_temp_mean_ws_120
# acc_phone_z_temp_mean_ws_120
# acc_watch_x_temp_mean_ws_120
# acc_watch_y_temp_mean_ws_120
# acc_watch_z_temp_mean_ws_120
# gyr_phone_x_temp_mean_ws_120
# gyr_phone_y_temp_mean_ws_120
# gyr_phone_z_temp_mean_ws_120
# gyr_watch_x_temp_mean_ws_120
# gyr_watch_y_temp_mean_ws_120
# gyr_watch_z_temp_mean_ws_120
# hr_watch_rate_temp_mean_ws_120
# light_phone_lux_temp_mean_ws_120
# mag_phone_x_temp_mean_ws_120
# ...

# %%
chap4new.eq(chap4old).sum()
# Out:
# Unnamed: 0                                   2895
# acc_phone_x                                     1
# acc_phone_x_freq_0.0_Hz_ws_40                  23
# acc_phone_x_freq_0.1_Hz_ws_40                   3
# acc_phone_x_freq_0.2_Hz_ws_40                   2
#                                              ...
# temp_pattern_labelStanding(b)labelWalking       0
# temp_pattern_labelWalking                       0
# temp_pattern_labelWalking(b)labelDriving        0
# temp_pattern_labelWalking(b)labelStanding       0
# temp_pattern_labelWalking(b)labelWalking        0
# Length: 542, dtype: int64

# %%
type(restold['pca_1'][0])
# Out:
# numpy.float64
